# %%
# !pip install webvtt-py
# Out:
# Collecting webvtt-py
#   Downloading https://files.pythonhosted.org/packages/c8/55/ecca9ee3276024dad3d68a856544ce836826be81e49b988c6ba8da6977b4/webvtt_py-0.4.5-py3-none-any.whl
# Requirement already satisfied: docopt in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from webvtt-py) (0.6.2)
# Installing collected packages: webvtt-py
# Successfully installed webvtt-py-0.4.5
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import webvtt

# %%
output=open('./output.txt', 'w')

for caption in webvtt.read('test.vtt'):
    output.write(caption.text + " ")

output.close()

# %%
output=open('./output.txt', 'r')

print(output.read())
# Out:
# Hello everyone and welcome to
# Unsw Redcap Tour one or short
# video series that covers more
# advanced redcap topics. Today's
# topic it started dictionary.
# A data dictionary is a document
# that describes the database,
# including how it's structured.
# The interactivity between data
# points. Another important
# metadata. In red cap there are
# two functionally distinct data
# dictionaries. One is termed the
# code book and the other data
# dictionary. The code book, which
# can be found on the top left
# hand side Navigation Pane is a
# read only human readable form of
# the data dictionary.
# Is serves as a quick reference
# for viewing the attributes of
# any given field in the project
# without having to download an
# interpret the data dictionary or
# access the online designer.
# Viewing these attributes are
# particularly useful when you are
# using piping or conditional
# logic or creating calculated
# fields as these required the
# unique variable or field name as
# well as the codes for options.
# For example, you wish to display
# a text field to specify when
# other is selected for favorite
# ice cream, but you do not
# remember the unique field name
# and code for other, you can
# simply come to code book.
# And find out.
# As the code book contains the
# entire project, you could
# collapse all instruments and
# open specific ones to search for
# fields of interest.
# On the other hand, the term data
# dictionary in red cab is used to
# specifically denote the
# modifiable machine readable
# form. This can be found either
# on the top left hand side
# Navigation Pane. Or in project
# setup. Design your data
# collection instruments
# and data dictionary.
# This form of data dictionary can
# be used in replacement of the
# online designer to create,
# modify, or delete instruments
# and fields within the project.
# It is particularly helpful when
# you wish to make large batches
# of changes to the project. For
# example, moving blocks of fields
# into different positions or
# adding branching logic to a
# number of fields. In contrast to
# the online designers pointing
# click method, the data
# dictionary allows you to
# download a comma separated
# values file. Or CSV file
# modified in a text or
# spreadsheet editor like Excel.
# Upload it again to see the
# changes implemented in the
# project. The data
# dictionary CSV file is
# arranged in a particular
# way. This makes it
# important to download the
# current data dictionary.
# So that you have a
# template to work with.
# In a data dictionary, each row
# represents a field.
# And the order of fields is
# determined by which ROH it
# occupies.
# Then each column represents each
# attribute for the fields. For
# example, there is a column for
# field name. There's a column for
# form name, which denotes the
# instrument in which the field
# resides. There is a field type
# which determines the type of
# field, like Textbox or radio
# button. Is also feel label
# nodes, validations and others.
# In this example, I wish to add a
# branching logic to a number of
# fields when someone can sense to
# participate in the study. So I
# type in the right logic in one
# field for the right column.
# The column for branching logic
# is here. So.
# I input. Consent.
# Equals 1 to denote when
# yes is selected for consent.
# And I copy this for all the
# other fields. That require
# this branching logic.
# Also, I want to create a new
# instrument and rearrange the
# fields. To do this, I cut the
# entire rose. This is very
# important and then insert it
# into the right spot.
# To create a new instrument
# that will contain these
# fields, I will rename the
# instrument to something else.
# Now when I
# save and upload
# the data dictionary.
# After a check by red cap.
# You can commit the changes
# and observe that the changes
# have been implemented.
# A few things to remember. One
# columns cannot be rearranged,
# only rose. Two instruments must
# be sequential in Rose. That is,
# when you go down the fields. If
# you go from instrument A to
# instrument B, going back to
# instrument a is not allowed.
# You need to position the fields
# in the order of instruments.
# 3 the data dictionary describes
# the entire project. All fields
# in all instruments. Therefore,
# if you wish to make updates,
# best practice is always to
# download the current data
# dictionary every time and modify
# this before uploading again.
# Four utilized the find and
# replace or auto fill function in
# Excel to make batches of
# changes, especially when you're
# duplicating instruments. 5 the
# survey settings cannot be added
# or changed in data dictionary.
# This must be done in online
# designer. To recap, today we
# covered the code book and data
# dictionary that describe the
# database structure while code
# book is read only human
# readable. The data dictionary
# is modifiable and machine
# readable. Data dictionary can
# be accessed in project set up
# and can be opened with a text
# or spreadsheet editor like
# Microsoft Excel.
# Finally, data dictionary
# allows for quick batch
# modifications and updates to
# the entire database
# structure.
